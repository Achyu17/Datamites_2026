# %% [markdown]
# ### Pandas
#  - Has reference to panel data as well as python data analysis
#  - Built on numpy
#  - Handling huge datasets

# %% [markdown]
# #### Data - Series/Data Frames

# %%
import numpy as np
import pandas as pd

# %%
np.__version__

# %%
#!pip install numpy==1.26
#pip install --force-reinstall numpy==1.26

# %%
#!pip uninstall numpy

# %%
#Series
list1 = [11,222,322,411]
arr = np.array([2,3,4,5])
tup1 = (1,2,34,5)
set1 = {3,4,6,7}
dict1 = {'row1': 1,'row2': 2, 'row3' : 3, 'row4' : 4}

# %%
pd.Series(list1,index=["a","b","c","d"],name='cds')

# %%
s = pd.Series(list1,index=['row1','row2','row3','row4'],name='Series1')

# %%
s

# %%
arr

# %%
s1 = pd.Series(arr)
s1

# %%
tup1

# %%
s2 = pd.Series(tup1)
s2

# %%
# s = pd.Series(set1)   #Not possible as set is unordered
# s

# %%
set1

# %%
dict1

# %%
s3 = pd.Series(dict1.keys())
#s3 = pd.Series(dict1)
s3

# %%
s = pd.Series(['Hi',2,3,4],index=['a','b','c','d'],name='Series1')
s

# %%
list2 = [[1,2,3,4],[23,4,5,6],[3,4,5,6],[1,2,3,4,7,8]]
df = pd.DataFrame(list2)
df

# %%
df.info()

# %%
#arr2 = np.array([[1,2,3],[2,3,4],[4,5,'r']])
arr2 = [[1,2,'r'],[3,4,5],[5,4,3]]
df = pd.DataFrame(arr2)
df

# %%
df.info(verbose=False)

# %%
df1 = pd.DataFrame([[1,2,3,4],[5,6],[7,8]])
df1

# %%
#Exercise: Create a dataframe with a series
ser1 = pd.Series()
df1 = pd.DataFrame(ser1)
print(ser1,df1)

# %%
arr2 = np.array([[1,2,3],[2,3,4],[4,5,7]])
df = pd.DataFrame(arr2,columns=['c1','c2','c3'])
df

# %%
df.rename(columns={'c1':'numbers'},inplace=True)

# %%
df

# %%
#Renaming columns
df.rename(columns={'c1':'col1','c2':'col2'},inplace=True)
#df.rename(columns={'c1':'col1','c2':'col2'})

# %%
df

# %%
df

# %%
df.c1

# %%
df['c3']

# %%
# inplace = True  ----  tells that changes are permanent

# %%
# df[0]   #---throws an error as columns are named

# %%
df.col1

# %%
df['col1']

# %% [markdown]
# ## File reading in pandas
# - Data is commonly read from files
# - different files like csv, tsv, excel, json

# %%
ls

# %%
data = pd.read_csv('train.csv')

# %%
#data = pd.read_csv()
# data1 = pd.read_csv(r'C:\Users\Om Computers\Downloads\main_data.csv')
# df2 = pd.read_excel(r'C:\Users\Om Computers\Downloads\Task 1_Optimisation (1).xlsx')

# df1 = pd.read_excel('ex1.xlsx',index_col = [0])
# df = pd.read_json('example.json')

# %%
data

# %%
#pd.set_option('display.max_rows',None)
#pd.reset_option('display.max_rows',None)
#pd.set_option('display.max_columns',None)
#pd.reset_option('display.max_columns',None)

# %% [markdown]
# ### Basic checks:
# - df.head()
# - df.tail()
# - df.info()
# - df.describe()
# - df.shape
# - df.columns
# - type(df)
# - df.colName.dtype
# - df.isnull()
# - df.isnull().sum()
# - df.colName.unique()
# - df.colName.value_counts()

# %%
data.head(6)

# %%
data.tail()

# %%
data.info()

# %%
data.describe

# %%
data.describe(include='O')

# %%
data.columns

# %%
data.shape

# %%
type(data)

# %%
data.Age.dtype

# %%
data.Name.dtype

# %%
#NULL Values:
data.isnull().sum()

# %%
data.Age.isnull().sum()

# %%
data.Cabin.isnull().sum()

# %%
data.Embarked.unique()

# %%
data.Embarked.value_counts()

# %%
data.Survived.value_counts()

# %% [markdown]
# ### Locating a value - Locaters
#  - df[col_name]
#  - df.col_name
#  - df[col_name][row_number]
#  - loc - locater -
#  - iloc - indexlocater
#
# # Experimenting with Non existing columns
# #df['Xyz']    #Returns a key error. Used to create new columns
# #df.Xyz       #Returns saying that df doesn't have the attribute

# %%
df

# %%
df['Xyz'][2] = 33
df

# %%
df['c1'][0]=333

# %%
df

# %%
#dir(df)  # To see the list of methods and atttributes of a dataframe

# %%
data.Survived

# %%
data['Survived']

# %%
data['Survived'][99]

# %%
data['Name'][99]

# %%
data.Name[2]

# %%
data['Survived'][34]

# %%
data.loc[34,"Survived"]

# %%
data.loc[34,'Name']

# %%
#df.iloc[rownum,colnum]
data.iloc[34,3]

# %%
data.columns

# %%
data.loc[[2,10,3],['Survived','Cabin','Parch']]

# %%
data.loc[[0,8],['Age','Survived']]

# %%
data.iloc[2:10,[4,1,8,3]]

# %%
data.columns

# %%
data.iloc[4:8,[1,5]]

# %%
data.iloc[4,2:6]
#data[4:5]
#data[10:20]

# %% [markdown]
# ### Filtering values
# - using loc and iloc

# %% [markdown]
# ### Filtering rows and columns based on loc and conditions
#  - Retrieve name, age and survival status of all passengers who are traveling in second class and aged above 60
#  - Retrieve name and Fare of passengers who boarded (embarked) at Cherbourgh (C)
#  - Get the details of passengers who are traveling alone

# %%
#data.loc[rows,columns]

# %%
data.columns

# %%
data.loc[(data.Pclass==2) & (data.Age > 60),['Name','Age','Survived']]

# %%
#Retrieve name, age and survival status of all passengers who are traveling in second class and aged above 60
data.loc[(data.Pclass==2) & (data.Age>60), ['Name','Age','Survived']]

# %%
#Retrieve name and Fare of passengers who boarded (embarked) at Cherbourgh (C)

# %%
data.columns

# %%
data.loc[(data.SibSp==0) & (data.Parch==0) & (data.Survived==0) & (data.Sex=='female')]

# %% [raw]
# - Get all names of passengers who boarded at 'Q'
# - Get the details of passengers who are traveling alone
# - Get the name and survival status of passengers who are traveling alone.
# - Get the name and age of female passengers who traveled in 3rd class.

# %%
np.where(data.Age>60)

# %%
data.iloc[np.where(data.Age>60)]

# %% [markdown]
# ### Creating new columns:

# %%
a = pd.DataFrame([[1,2,3],[4,5,6],[6,5,4]], columns = ['col1','col2','col3'])
a

# %%
a['Total'] = 'Tot'
a

# %%
a['Total2'] = ['Tot','Tet',3]
a

# %%
a['Total3'] = a['col1']+a['col2']+a['col3']
a

# %%
#Creating a new columns
s1 = pd.Series([1,2,3,4],name='col1')
s1

# %%
s2 = pd.Series([11,21,31,41],name='col2')
s3 = pd.Series([31,32,33,34],name='col3')
df = pd.DataFrame(s1)

# %%
s2

# %%
df

# %%
df = pd.concat([df,s3],axis=1)
df
#Create a dataframe with same col names as the original and try concat function with axis 0

# %%
z = pd.concat([s2,df],axis=0)
z

# %%
#How to add a row?
new_row = pd.DataFrame({'col1':[5],'col3':[6]})
new_row

# %%
df

# %%
pd.concat([df,new_row]).reset_index(drop=True)

# %% [markdown]
# ## Cleaning/Manipulating the data
# - Dropping columns - dropna(), drop, drop_duplicates()
# - Check for duplicates using data.duplicated()
# - Imputing values

# %%
data.head(2)

# %%
#data.duplicated()   #----- Returns a boolean array of T/F based on dupliate status of the row.
data.duplicated().sum()    # ------ Gives you total number of duplicate rows
#data.loc[data.duplicated()]     #  ----- Retrieve all the duplicate rows
#data.drop_duplicates(inplace=True)

# %%
a = pd.DataFrame([[1,2,3],[1,2,3],[5,6,7]], columns = ['col1','col2','col3'])
a

# %%
a.duplicated().sum()

# %%
a.drop_duplicates(inplace=True)
a

# %%
data.isnull().sum()

# %%
#data.info()
data.dropna()

# %%
data.info()

# %%
#out of 891,only 204 non null values
data.drop(['Cabin'],axis=1,inplace=True)

# %%
data.columns

# %%
data.info()

# %%
data

# %%
z

# %%
z.fillna(value={ 'col1': 23, 'col3': z.col3.mean()})

# %%
data.isnull().sum()

# %%
#data.fillna(0)
data.fillna(value={'Age':data.Age.mean(),'Embarked':'S'},inplace=True)
#data.fillna(value={'col1':'A','col2':data.col2.mean(),'col3':data.col3.median(),'col4':0},axis=1)

# %%
data.isnull().sum()

# %%
data.Embarked.value_counts()

# %%
data.Embarked.isnull().sum()

# %%
#Another way of imputing
data.loc[data.Embarked.isnull(),'Embarked'] = 'S'

# %%
np.where(data.Pclass==1)

# %%
#Imputing values - fillna(0)
data.loc[data.Age <1 ,'Age'] = 0

# %%
data.loc[data.Age.isnull()]

# %% [markdown]
# ### Sorting dataframe

# %%
#Sorting
data.sort_values('Fare',ascending=False)
#data.sort_values('Age',ignore_index=True,inplace=True)

# %%
data

# %%
data.groupby('Sex')['Age'].mean()

# %%
data.groupby('Sex')['Fare'].mean()

# %%
data.groupby('Pclass')['Age'].mean()

# %%
data.groupby('Sex')['Fare'].mean()

# %%
#Group by functions
data.groupby('Pclass')['Fare'].mean()

# %%
# pd.set_option('display.max_columns',None)
# data.groupby('Sex').describe()

# %%
#data.groupby('Sex')['Age'].describe()
#data.groupby('Sex')['Age'].sum()
#data.groupby('Sex')['Age'].count()
#data.groupby('Sex')['Age'].mean()
data.loc[data.Survived==1].groupby('Sex')['Sex'].count()
#data.groupby('Sex')['Age'].median()

# %%
#Aggregators sum(),mean(),min(),max(),median(),std(),var(),avg(),describe()
data.groupby('Embarked')['Survived'].sum()

# %%
data.info()

# %% [markdown]
# ## Changing the datatype
# - astype - int to float, int/float to object
# - to_numeric

# %%
data.info()

# %%
data.describe()

# %%
data.describe(include='O')

# %%
data.info()
data['Survived'] = data.Survived.astype('int32')

# %%
data.info()

# %%
data['Pclass'] = data.Pclass.astype('int')

# %%
data['SibSp'] = pd.to_numeric(data.SibSp,downcast='integer')

# %%
data.info()
