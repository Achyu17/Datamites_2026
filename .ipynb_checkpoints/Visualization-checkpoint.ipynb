# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=pd.Series([1,2,3,4,5,6,7,7,8])
y=pd.Series([3,4,5,1,2,3,9,10,7])
plt.figure(figsize=(15,3))
plt.xlabel('this is x axis')
plt.ylabel('this is y axis')
plt.title('Graph')

plt.plot(x,y,linestyle='dotted',marker='*',color='blue')
plt.show()

# %% [markdown]
# # Seaborn

# %%
np.__version__
# Out:
# '2.1.3'

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.lineplot(data=df,x='sepal_length',y='sepal_width',color='blue')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(data=df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x=df.sepal_length,y=df.sepal_width,data=df,hue=df.species)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>
